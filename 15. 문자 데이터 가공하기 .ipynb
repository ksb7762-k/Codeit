# %% [markdown]
# # 1. 대소문자 처리하기(pandas 함수 몇 가지 소개)

# %%
import pandas as pd
airbnb_df = pd.read_csv('data/airbnb.csv')
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  MASSACHUSETTS       4     1     Apartment     NaN          0
# 2    OZ5857       ILLINOIS       4     3     Apartment   100.0         51
# 3    HY8797     california       2     1     Apartment    75.0          4
# 4    VN7858  massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     california       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       ILLINOIS       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# 0             Avondale, Chicago.     48
# 1             South End, Boston.    115
# 2             Avondale, Chicago.    150
# 3           SoMa, San Francisco.    125
# 4          West Roxbury, Boston.     64
# ..                           ...    ...
# 708         Venice, Los Angeles.    150
# 709   Mid-Wilshire, Los Angeles.    100
# 710  Redondo Beach, Los Angeles.    100
# 711           Lakeview, Chicago.    115
# 712         East Boston, Boston.    115
#
# [713 rows x 9 columns]

# %%
airbnb_df['state'].unique()
# Out:
# array(['Illinois', 'MASSACHUSETTS', 'ILLINOIS', 'california',
#        'massachusetts', 'California', 'Massachusetts', 'CALIFORNIA',
#        'illinois'], dtype=object)

# %%
airbnb_df['state'].str.lower()
# Out:
# 0           illinois
# 1      massachusetts
# 2           illinois
# 3         california
# 4      massachusetts
#            ...
# 708       california
# 709       california
# 710       california
# 711         illinois
# 712    massachusetts
# Name: state, Length: 713, dtype: object

# %%
airbnb_df['state'].str.upper()
# Out:
# 0           ILLINOIS
# 1      MASSACHUSETTS
# 2           ILLINOIS
# 3         CALIFORNIA
# 4      MASSACHUSETTS
#            ...
# 708       CALIFORNIA
# 709       CALIFORNIA
# 710       CALIFORNIA
# 711         ILLINOIS
# 712    MASSACHUSETTS
# Name: state, Length: 713, dtype: object

# %%
airbnb_df['state'].str.capitalize()
# Out:
# 0           Illinois
# 1      Massachusetts
# 2           Illinois
# 3         California
# 4      Massachusetts
#            ...
# 708       California
# 709       California
# 710       California
# 711         Illinois
# 712    Massachusetts
# Name: state, Length: 713, dtype: object

# %%
airbnb_df['state'] = airbnb_df['state'].str.capitalize()

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# 0             Avondale, Chicago.     48
# 1             South End, Boston.    115
# 2             Avondale, Chicago.    150
# 3           SoMa, San Francisco.    125
# 4          West Roxbury, Boston.     64
# ..                           ...    ...
# 708         Venice, Los Angeles.    150
# 709   Mid-Wilshire, Los Angeles.    100
# 710  Redondo Beach, Los Angeles.    100
# 711           Lakeview, Chicago.    115
# 712         East Boston, Boston.    115
#
# [713 rows x 9 columns]

# %% [markdown]
# # 02. 문자열 분리하기

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price
# 0             Avondale, Chicago.     48
# 1             South End, Boston.    115
# 2             Avondale, Chicago.    150
# 3           SoMa, San Francisco.    125
# 4          West Roxbury, Boston.     64
# ..                           ...    ...
# 708         Venice, Los Angeles.    150
# 709   Mid-Wilshire, Los Angeles.    100
# 710  Redondo Beach, Los Angeles.    100
# 711           Lakeview, Chicago.    115
# 712         East Boston, Boston.    115
#
# [713 rows x 9 columns]

# %%
airbnb_df['location'].str.split(',')
# Out:
# 0               [Avondale,  Chicago.]
# 1               [South End,  Boston.]
# 2               [Avondale,  Chicago.]
# 3             [SoMa,  San Francisco.]
# 4            [West Roxbury,  Boston.]
#                     ...
# 708           [Venice,  Los Angeles.]
# 709     [Mid-Wilshire,  Los Angeles.]
# 710    [Redondo Beach,  Los Angeles.]
# 711             [Lakeview,  Chicago.]
# 712           [East Boston,  Boston.]
# Name: location, Length: 713, dtype: object

# %%
airbnb_df['location'].str.split(',').str[0]
# Out:
# 0           Avondale
# 1          South End
# 2           Avondale
# 3               SoMa
# 4       West Roxbury
#            ...
# 708           Venice
# 709     Mid-Wilshire
# 710    Redondo Beach
# 711         Lakeview
# 712      East Boston
# Name: location, Length: 713, dtype: object

# %%
airbnb_df['neighborhood'] = airbnb_df['location'].str.split(',').str[0]

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price   neighborhood
# 0             Avondale, Chicago.     48       Avondale
# 1             South End, Boston.    115      South End
# 2             Avondale, Chicago.    150       Avondale
# 3           SoMa, San Francisco.    125           SoMa
# 4          West Roxbury, Boston.     64   West Roxbury
# ..                           ...    ...            ...
# 708         Venice, Los Angeles.    150         Venice
# 709   Mid-Wilshire, Los Angeles.    100   Mid-Wilshire
# 710  Redondo Beach, Los Angeles.    100  Redondo Beach
# 711           Lakeview, Chicago.    115       Lakeview
# 712         East Boston, Boston.    115    East Boston
#
# [713 rows x 10 columns]

# %%
airbnb_df['city'] = airbnb_df['location'].str.split(',').str[1]

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#                         location  price   neighborhood             city
# 0             Avondale, Chicago.     48       Avondale         Chicago.
# 1             South End, Boston.    115      South End          Boston.
# 2             Avondale, Chicago.    150       Avondale         Chicago.
# 3           SoMa, San Francisco.    125           SoMa   San Francisco.
# 4          West Roxbury, Boston.     64   West Roxbury          Boston.
# ..                           ...    ...            ...              ...
# 708         Venice, Los Angeles.    150         Venice     Los Angeles.
# 709   Mid-Wilshire, Los Angeles.    100   Mid-Wilshire     Los Angeles.
# 710  Redondo Beach, Los Angeles.    100  Redondo Beach     Los Angeles.
# 711           Lakeview, Chicago.    115       Lakeview         Chicago.
# 712         East Boston, Boston.    115    East Boston          Boston.
#
# [713 rows x 11 columns]

# %%
airbnb_df = airbnb_df.drop(columns='location')

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#      price   neighborhood             city
# 0       48       Avondale         Chicago.
# 1      115      South End          Boston.
# 2      150       Avondale         Chicago.
# 3      125           SoMa   San Francisco.
# 4       64   West Roxbury          Boston.
# ..     ...            ...              ...
# 708    150         Venice     Los Angeles.
# 709    100   Mid-Wilshire     Los Angeles.
# 710    100  Redondo Beach     Los Angeles.
# 711    115       Lakeview         Chicago.
# 712    115    East Boston          Boston.
#
# [713 rows x 10 columns]

# %% [markdown]
# # 03. 불필요한 문자 제거하기

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#      price   neighborhood             city
# 0       48       Avondale         Chicago.
# 1      115      South End          Boston.
# 2      150       Avondale         Chicago.
# 3      125           SoMa   San Francisco.
# 4       64   West Roxbury          Boston.
# ..     ...            ...              ...
# 708    150         Venice     Los Angeles.
# 709    100   Mid-Wilshire     Los Angeles.
# 710    100  Redondo Beach     Los Angeles.
# 711    115       Lakeview         Chicago.
# 712    115    East Boston          Boston.
#
# [713 rows x 10 columns]

# %%
airbnb_df[airbnb_df['city'] == 'Boston']
# Out:
# Empty DataFrame
# Columns: [id, state, guests, beds, property_type, rating, n_reviews, price, neighborhood, city]
# Index: []

# %%
airbnb_df['city'].unique()
# Out:
# array([' Chicago.', ' Boston.', ' San Francisco.', ' Los Angeles.'],
#       dtype=object)

# %% [markdown]
# ## 컴퓨터는 code에 있는 Boston과 array에 있는 Boston을 다른 문자열로 인식함(공백과 점이 있기 때문)

# %%
airbnb_df['city'].str.strip()
# Out:
# 0            Chicago.
# 1             Boston.
# 2            Chicago.
# 3      San Francisco.
# 4             Boston.
#             ...
# 708      Los Angeles.
# 709      Los Angeles.
# 710      Los Angeles.
# 711          Chicago.
# 712           Boston.
# Name: city, Length: 713, dtype: object

# %%
airbnb_df['city'] = airbnb_df['city'].str.strip() # strip 공백을 없애는 함수

# %%
airbnb_df['city'].str.replace('.', '', regex=False)
# Out:
# 0            Chicago
# 1             Boston
# 2            Chicago
# 3      San Francisco
# 4             Boston
#            ...
# 708      Los Angeles
# 709      Los Angeles
# 710      Los Angeles
# 711          Chicago
# 712           Boston
# Name: city, Length: 713, dtype: object

# %%
airbnb_df['city'] = airbnb_df['city'].str.replace('.', '', regex=False)

# %%
airbnb_df
# Out:
#          id          state  guests  beds property_type  rating  n_reviews  \
# 0    BF1406       Illinois       2     1     Apartment    96.0         55
# 1    DB7921  Massachusetts       4     1     Apartment     NaN          0
# 2    OZ5857       Illinois       4     3     Apartment   100.0         51
# 3    HY8797     California       2     1     Apartment    75.0          4
# 4    VN7858  Massachusetts       2     1         House    88.0         23
# ..      ...            ...     ...   ...           ...     ...        ...
# 708  XG3289     California       2     1     Apartment    97.0         60
# 709  ZR5298     California       4     2     Apartment    93.0          3
# 710  XZ5531     California       2     1      Bungalow    93.0          3
# 711  EE8333       Illinois       2     1         House    80.0         15
# 712  AA6024  Massachusetts       3     1     Apartment    96.0         61
#
#      price   neighborhood           city
# 0       48       Avondale        Chicago
# 1      115      South End         Boston
# 2      150       Avondale        Chicago
# 3      125           SoMa  San Francisco
# 4       64   West Roxbury         Boston
# ..     ...            ...            ...
# 708    150         Venice    Los Angeles
# 709    100   Mid-Wilshire    Los Angeles
# 710    100  Redondo Beach    Los Angeles
# 711    115       Lakeview        Chicago
# 712    115    East Boston         Boston
#
# [713 rows x 10 columns]

# %%
airbnb_df['city'].str.strip().str.replace('.', '', regex=False)
# Out:
# 0            Chicago
# 1             Boston
# 2            Chicago
# 3      San Francisco
# 4             Boston
#            ...
# 708      Los Angeles
# 709      Los Angeles
# 710      Los Angeles
# 711          Chicago
# 712           Boston
# Name: city, Length: 713, dtype: object

# %% [markdown]
# # 04. 문자 데이터 처리하기 실습

# %% [markdown]
# ### 실습 설명
# ### 효준이가 수집한 핸드폰 데이터를 좀 더 사용하기 좋게 전처리해 봅시다. 아래에 쓰여 있는 대로 brand, name, size 컬럼에 있는 데이터를 가공해 주세요.
# ### brand 컬럼에 저장된 제조사명의 대소문자 표기를 통일해 주세요. 첫 글자는 대문자로, 나머지 글자는 소문자로 바꿔 주시면 됩니다.
# ### name 컬럼에는 iPhone 14 Pro (256GB)와 같이 스마트폰의 모델명(iPhone 14 Pro)과 용량(256GB) 정보가 함께 들어 있습니다. 모델과 용량을 쉽게 구분해서 볼 수 있도록 문자열을 분리해 주세요. 모델명은 model 컬럼, 용량은 capacity 컬럼에 저장하고, 기존의 name 컬럼은 삭제하면 됩니다. 모델명 앞뒤에 불필요한 공백 문자열이 없도록 처리하는 것도 잊지 마세요!
# ### size 컬럼에는 스마트폰의 디스플레이 크기 정보가 담겨 있습니다. 그런데 데이터에 인치(inch)를 나타내는 " 기호가 들어 있어서 pandas가 이 컬럼의 데이터 타입을 문자 데이터로 인식하고 있네요. " 기호를 없앤 뒤 size 컬럼의 데이터 타입을 적절한 숫자 타입으로 바꿔 주세요.
#
# ## 실습 결과
# ![image.png](attachment:3a656ee4-78c0-4219-b549-55d56b91534f.png)

# %%
cellphone_df = pd.read_csv('data/cellphone.csv')
cellphone_df
# Out:
#       brand                                        name  size   price  \
# 0     apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     APPLE                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  SAMSUNG                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  SAMSUNG                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# 3      4325   203.0  2022
# 4      4325   203.0  2022
# ..      ...     ...   ...
# 65     5000   220.0  2020
# 66     4500   186.0  2020
# 67     3300   183.0  2020
# 68     4500   282.0  2020
# 69     4500   282.0  2020
#
# [70 rows x 7 columns]

# %%
cellphone_df['brand'].str.capitalize()
# Out:
# 0       Apple
# 1       Apple
# 2       Apple
# 3       Apple
# 4       Apple
#        ...
# 65    Samsung
# 66    Samsung
# 67    Samsung
# 68    Samsung
# 69    Samsung
# Name: brand, Length: 70, dtype: object

# %%
cellphone_df['brand'] = cellphone_df['brand'].str.capitalize()
cellphone_df
# Out:
#       brand                                        name  size   price  \
# 0     Apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     Apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     Apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     Apple                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  Samsung                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  Samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  Samsung                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  Samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year
# 0      3729   172.0  2022
# 1      3729   172.0  2022
# 2      3729   172.0  2022
# 3      4325   203.0  2022
# 4      4325   203.0  2022
# ..      ...     ...   ...
# 65     5000   220.0  2020
# 66     4500   186.0  2020
# 67     3300   183.0  2020
# 68     4500   282.0  2020
# 69     4500   282.0  2020
#
# [70 rows x 7 columns]

# %%
cellphone_df['name'].str.split('(')
# Out:
# 0                              [iPhone 14 , 128GB)]
# 1                              [iPhone 14 , 256GB)]
# 2                              [iPhone 14 , 512GB)]
# 3                         [iPhone 14 Plus , 128GB)]
# 4                         [iPhone 14 Plus , 256GB)]
#                           ...
# 65                      [Galaxy S20 Ultra , 512GB)]
# 66                           [Galaxy S20+ , 256GB)]
# 67                        [Galaxy Z Flip2 , 256GB)]
# 68                        [Galaxy Z Fold2 , 256GB)]
# 69    [Galaxy Z Fold2 Thom Browne Edition , 256GB)]
# Name: name, Length: 70, dtype: object

# %%
cellphone_df['name'].str.split('(').str[0]
# Out:
# 0                              iPhone 14
# 1                              iPhone 14
# 2                              iPhone 14
# 3                         iPhone 14 Plus
# 4                         iPhone 14 Plus
#                      ...
# 65                      Galaxy S20 Ultra
# 66                           Galaxy S20+
# 67                        Galaxy Z Flip2
# 68                        Galaxy Z Fold2
# 69    Galaxy Z Fold2 Thom Browne Edition
# Name: name, Length: 70, dtype: object

# %%
cellphone_df['model'] = cellphone_df['name'].str.split('(').str[0]
cellphone_df
# Out:
#       brand                                        name  size   price  \
# 0     Apple                           iPhone 14 (128GB)  6.1"  1250.0
# 1     Apple                           iPhone 14 (256GB)  6.1"  1400.0
# 2     Apple                           iPhone 14 (512GB)  6.1"  1700.0
# 3     Apple                      iPhone 14 Plus (128GB)  6.7"  1350.0
# 4     Apple                      iPhone 14 Plus (256GB)  6.7"  1500.0
# ..      ...                                         ...   ...     ...
# 65  Samsung                    Galaxy S20 Ultra (512GB)  6.9"  1793.0
# 66  Samsung                         Galaxy S20+ (256GB)  6.7"  1353.0
# 67  Samsung                      Galaxy Z Flip2 (256GB)  6.7"  1650.0
# 68  Samsung                      Galaxy Z Fold2 (256GB)  7.6"  1892.0
# 69  Samsung  Galaxy Z Fold2 Thom Browne Edition (256GB)  7.6"  3960.0
#
#     battery  weight  year                                model
# 0      3729   172.0  2022                           iPhone 14
# 1      3729   172.0  2022                           iPhone 14
# 2      3729   172.0  2022                           iPhone 14
# 3      4325   203.0  2022                      iPhone 14 Plus
# 4      4325   203.0  2022                      iPhone 14 Plus
# ..      ...     ...   ...                                  ...
# 65     5000   220.0  2020                    Galaxy S20 Ultra
# 66     4500   186.0  2020                         Galaxy S20+
# 67     3300   183.0  2020                      Galaxy Z Flip2
# 68     4500   282.0  2020                      Galaxy Z Fold2
# 69     4500   282.0  2020  Galaxy Z Fold2 Thom Browne Edition
#
# [70 rows x 8 columns]

# %%
cellphone_df['name'].str.split('(').str[1]
# Out:
# 0     128GB)
# 1     256GB)
# 2     512GB)
# 3     128GB)
# 4     256GB)
#        ...
# 65    512GB)
# 66    256GB)
# 67    256GB)
# 68    256GB)
# 69    256GB)
# Name: name, Length: 70, dtype: object

# %%
cellphone_df['capacity'] = cellphone_df['name'].str.split('(').str[1]

# %%
cellphone_df['model'] = cellphone_df['model'].str.strip()
cellphone_df['capacity'] = cellphone_df['model'].str.replace(')', '')

# %%
cellphone_df = cellphone_df.drop(columns='name')

cellphone_df['size'] = cellphone_df['size'].str.replace('"', '').astype('float')
cellphone_df
# Out:
#       brand  size   price  battery  weight  year  \
# 0     Apple   6.1  1250.0     3729   172.0  2022
# 1     Apple   6.1  1400.0     3729   172.0  2022
# 2     Apple   6.1  1700.0     3729   172.0  2022
# 3     Apple   6.7  1350.0     4325   203.0  2022
# 4     Apple   6.7  1500.0     4325   203.0  2022
# ..      ...   ...     ...      ...     ...   ...
# 65  Samsung   6.9  1793.0     5000   220.0  2020
# 66  Samsung   6.7  1353.0     4500   186.0  2020
# 67  Samsung   6.7  1650.0     3300   183.0  2020
# 68  Samsung   7.6  1892.0     4500   282.0  2020
# 69  Samsung   7.6  3960.0     4500   282.0  2020
#
#                                  model                            capacity
# 0                            iPhone 14                           iPhone 14
# 1                            iPhone 14                           iPhone 14
# 2                            iPhone 14                           iPhone 14
# 3                       iPhone 14 Plus                      iPhone 14 Plus
# 4                       iPhone 14 Plus                      iPhone 14 Plus
# ..                                 ...                                 ...
# 65                    Galaxy S20 Ultra                    Galaxy S20 Ultra
# 66                         Galaxy S20+                         Galaxy S20+
# 67                      Galaxy Z Flip2                      Galaxy Z Flip2
# 68                      Galaxy Z Fold2                      Galaxy Z Fold2
# 69  Galaxy Z Fold2 Thom Browne Edition  Galaxy Z Fold2 Thom Browne Edition
#
# [70 rows x 8 columns]
