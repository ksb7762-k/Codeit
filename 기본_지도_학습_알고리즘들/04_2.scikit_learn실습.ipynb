# %% [markdown]
# <a href="https://colab.research.google.com/github/ksb7762-k/Codeit/blob/main/04_2_scikit_learn%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
iris_data = load_iris()

# %%
print(iris_data.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
x= pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

# %%
y= pd.DataFrame(iris_data.target, columns=['class'])

# %%
y
# Out:
#      class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 5)

# %%
y_train = y_train.values.ravel() # 이 코드를 안써도 되긴 한데 경고가 뜸

# %%
 model = LogisticRegression(solver='saga', max_iter=2000)    # solver : 모델을 최적화할 때 어떤 알고리즘을 쓸지 결정, max_iter : 최적화를 할 때 그 과정을 몇 번 반복할지 결정 , 학습률 알파는 자동으로 설정

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=2000, solver='saga')

# %%
model.predict(x_test)
# Out:
# array([1, 2, 2, 0, 2, 1, 0, 2, 0, 1, 1, 2, 2, 2, 0, 0, 2, 2, 0, 0, 1, 2,
#        0, 1, 1, 2, 1, 1, 1, 2])

# %%
model.score(x_test, y_test)
# Out:
# 0.9666666666666667
